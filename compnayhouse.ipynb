# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://beta.companieshouse.gov.uk/company/07812420")

# %%
soup = BeautifulSoup(page.content, "html.parser")
#print(soup)

# %%
#list(soup.children)

# %%
#[type(item) for item in list(soup.children)]

# %%
html = list(soup.children)[5]
print(html)
soup.select('div[id="content-container"]')
print(soup)
# Out:
# <html lang="en"><!--<![endif]--><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <!-- Company numbers are not taken as a phone number -->
# <meta content="telephone=no" name="format-detection"/>
# <title>SYNGCO LIMITED - Overview (free company information from Companies House)</title>
# <meta content="SYNGCO LIMITED - Free company information from Companies House including registered office address, filing history, accounts, annual return, officers, charges, business activity" name="description"/>
# <script>
#       (function(){if(navigator.userAgent.match(/IEMobile\/10\.0/)){var d=document,c="appendChild",a=d.createElement("style");a[c](d.createTextNode("@-ms-viewport{width:auto!important}"));d.getElementsByTagName("head")[0][c](a);}})();
#    </script>
# ...
